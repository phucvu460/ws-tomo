# %%
from Mailbox import mail_box
import math
import time

# %%
import time
from Serial_Communication import Serial_controller
ser_left = Serial_controller.SERIAL_MAIN_CONTROLLER('/dev/ttyUSB1')
# ser_right = Serial_controller.SERIAL_MAIN_CONTROLLER('/dev/ttyUSB0')
# Out:
# Serial port is initialized!

# %%
mail = mail_box.MAIL_BOX()


left_arm_0 = 0
left_arm_1 = 1
left_arm_2 = 2 
left_arm_3 = 3
left_arm_4 = 4 
left_arm_5 = 5 
head_1 = 6 
head_2 = 7
right_arm_0 = 8
right_arm_1 = 9
right_arm_2 = 10
right_arm_3 = 11
right_arm_4 = 12
right_arm_5 = 13
# Out:
# shoulder_1
# SlaveInfo(ID=0, DRIVER_TYPE='GOLD_DRIVE', BELONG_TO='arm', PARSING_INFO='<iIHIIIb', JOINT_NAME='shoulder_1', GEAR_RATIO=100, ENCODER_RES=65536, TARGET_DEACCE=5000, TARGET_ACCE=5000, TARGET_VELOCITY=5000, ACTUAL_TORQUE=0, TARGET_POS=0, TARGET_REACH=False, CONTROL_WORD=0, STATUS_WORD=0, MODE_OF_OPERATION=1, DIGITAL_OUTPUT=0, ACTUAL_POS=0, DIGITAL_INPUT=0, ACTUAL_VELOCITY=0, DRIVE_DEF=<module 'Ethercat_Communication.Gold_drive_definition' from '/home/joey/ws_moveit/src/TOMO_final/software/Ethercat_Communication/Gold_drive_definition.py'>)
# shoulder_2
# ...

# %%
mail.servo_on(0)
mail.servo_on(1)
mail.servo_on(2)
mail.servo_on(3)
mail.servo_on(4)
mail.servo_on(5)
mail.servo_on(6)
mail.servo_on(7)
mail.servo_on(8)
mail.servo_on(9)
mail.servo_on(10)
mail.servo_on(11)
mail.servo_on(12)
mail.servo_on(13)

# %%
mail.servo_on(6)
mail.servo_on(7)

# %%
mail.move_to_position(6,1000,3)
# Out:
# current_pos:  0.0
# current velocity:  None
# move_array:  [23989870   334680   371866   371866]
# set_ epos4

# %%
def open_2finger_same_type(_type,velocity,accelerate ):

    if _type == 'index_finger':
        ser_left.set_motor_data(3,-10,velocity,accelerate,True)
        ser_left.set_motor_data(3,-10,velocity,accelerate,True)
        ser_left.set_motor_data(3,-10,velocity,accelerate,True)
        ser_left.set_motor_data(3,-10,velocity,accelerate,True)
#         time.sleep(0.1)
#         ser_right.set_motor_data(1,-10,velocity,accelerate,True)
#         ser_right.set_motor_data(1,-10,velocity,accelerate,True)
#         ser_right.set_motor_data(1,-10,velocity,accelerate,True)
#         ser_right.set_motor_data(1,-10,velocity,accelerate,True)

        
    if _type == 'middle_finger':
        ser_left.set_motor_data(4,-10,velocity,accelerate,True)
        ser_left.set_motor_data(4,-10,velocity,accelerate,True)
        ser_left.set_motor_data(4,-10,velocity,accelerate,True)
        ser_left.set_motor_data(4,-10,velocity,accelerate,True)

#         time.sleep(0.1)
#         ser_right.set_motor_data(2,-10,velocity,accelerate,True)
#         ser_right.set_motor_data(2,-10,velocity,accelerate,True)
#         ser_right.set_motor_data(2,-10,velocity,accelerate,True)
#         ser_right.set_motor_data(2,-10,velocity,accelerate,True)

    if _type == 'ring_finger':
        ser_left.set_motor_data(5,-10,velocity,accelerate,True)
        ser_left.set_motor_data(5,-10,velocity,accelerate,True)
        ser_left.set_motor_data(5,-10,velocity,accelerate,True)
        ser_left.set_motor_data(5,-10,velocity,accelerate,True)
#         time.sleep(0.1)
#         ser_right.set_motor_data(3,-10,velocity,accelerate,True)
#         ser_right.set_motor_data(3,-10,velocity,accelerate,True)
#         ser_right.set_motor_data(3,-10,velocity,accelerate,True)
#         ser_right.set_motor_data(3,-10,velocity,accelerate,True)

    if _type == 'pinky_finger':
        ser_left.set_motor_data(6,-10,velocity,accelerate,True)
        ser_left.set_motor_data(6,-10,velocity,accelerate,True)
        ser_left.set_motor_data(6,-10,velocity,accelerate,True)
        ser_left.set_motor_data(6,-10,velocity,accelerate,True)

        
def close_2finger_same_type(_type,position,velocity,accelerate ):
#     if position > 0:
#         position = 0
    if _type == 'index_finger':
        ser_left.set_motor_data(3,position,velocity,accelerate,True)
        ser_left.set_motor_data(3,position,velocity,accelerate,True)
        ser_left.set_motor_data(3,position,velocity,accelerate,True)
        ser_left.set_motor_data(3,position,velocity,accelerate,True)

#         time.sleep(0.1)
#         ser_right.set_motor_data(1,position,velocity,accelerate,True)
#         ser_right.set_motor_data(1,position,velocity,accelerate,True)
#         ser_right.set_motor_data(1,position,velocity,accelerate,True)
#         ser_right.set_motor_data(1,position,velocity,accelerate,True)
        
    if _type == 'middle_finger':
        ser_left.set_motor_data(4,position,velocity,accelerate,True)
        ser_left.set_motor_data(4,position,velocity,accelerate,True)
        ser_left.set_motor_data(4,position,velocity,accelerate,True)
        ser_left.set_motor_data(4,position,velocity,accelerate,True)

#         time.sleep(0.1)

#         ser_right.set_motor_data(2,position,velocity,accelerate,True)
#         ser_right.set_motor_data(2,position,velocity,accelerate,True)
#         ser_right.set_motor_data(2,position,velocity,accelerate,True)
#         ser_right.set_motor_data(2,position,velocity,accelerate,True)
        
    if _type == 'ring_finger':
        ser_left.set_motor_data(5,position,velocity,accelerate,True)
        ser_left.set_motor_data(5,position,velocity,accelerate,True)
        ser_left.set_motor_data(5,position,velocity,accelerate,True)
        ser_left.set_motor_data(5,position,velocity,accelerate,True)
        
#         time.sleep(0.1)
        
#         ser_right.set_motor_data(3,position,velocity,accelerate,True)
#         ser_right.set_motor_data(3,position,velocity,accelerate,True)
#         ser_right.set_motor_data(3,position,velocity,accelerate,True)
#         ser_right.set_motor_data(3,position,velocity,accelerate,True)

    if _type == 'pinky_finger':
        ser_left.set_motor_data(6,position,velocity,accelerate,True)
        ser_left.set_motor_data(6,position,velocity,accelerate,True)
        ser_left.set_motor_data(6,position,velocity,accelerate,True)
        ser_left.set_motor_data(6,position,velocity,accelerate,True)

# %%
_velo = 700
_acce = 500
for i in range(10):
    close_2finger_same_type('index_finger',1600,_velo,_acce )
    close_2finger_same_type('middle_finger',1600,_velo,_acce )
    close_2finger_same_type('ring_finger',1600,_velo,_acce )
    close_2finger_same_type('pinky_finger',1600,_velo,_acce )
    time.sleep(5)

    open_2finger_same_type('index_finger',_velo,_acce)
    open_2finger_same_type('middle_finger',_velo,_acce)
    open_2finger_same_type('ring_finger',_velo,_acce)
    open_2finger_same_type('pinky_finger',_velo,_acce)
    time.sleep(5)

# %%
_velo = 700
_acce = 500
# close_2finger_same_type('pinky_finger',1600,_velo,_acce )
open_2finger_same_type('pinky_finger',_velo,_acce)

# %%
########################running nowwwwwwwwwww
time_3 = 10

####################################
#left_hand
#_velo = 700
#_acce = 500
#ser_left.set_motor_data(3,0,_velo,_acce,True) #index finger up -> +
#ser_left.set_motor_data(4,1600,_velo,_acce,True) #middle finger up -> +
#ser_left.set_motor_data(5,1600,_velo,_acce,True) #ring finger up -> +
#ser_left.set_motor_data(6,1600,_velo,_acce,True) #little finger up -> +
#teach_index_finger
#init position
mail.move_to_position(left_arm_0,-1.524,time_3)
mail.move_to_position(left_arm_1,0.77,time_3)
mail.move_to_position(right_arm_0,1.61,time_3)
mail.move_to_position(right_arm_1,-0.854,time_3)

time.sleep(time_3/2)

mail.move_to_position(left_arm_2,1.53,time_3)
mail.move_to_position(left_arm_4,0.01,time_3)
mail.move_to_position(left_arm_5,0.175,time_3)



mail.move_to_position(right_arm_2,-1.62,time_3)
mail.move_to_position(right_arm_4,0.12,time_3)
mail.move_to_position(right_arm_5,0.23,time_3)

time.sleep(time_3)

mail.move_to_position(left_arm_3,0.17,time_3/2)
mail.move_to_position(right_arm_3,-0.15,time_3/2)

time.sleep(time_3)
for i in range(100000000):

    #open arm
    mail.move_to_position(right_arm_3,0,time_3/2)
    mail.move_to_position(left_arm_3,0,time_3/2)

    
    time.sleep(time_3/2)
    #open_hand
#     ser_left.set_motor_data(3,0,_velo,_acce,True) #index finger up -> +
#     ser_left.set_motor_data(4,0,_velo,_acce,True) #middle finger up -> +
#     ser_left.set_motor_data(5,0,_velo,_acce,True) #ring finger up -> +
#     ser_left.set_motor_data(6,0,_velo,_acce,True) #little finger up -> +
    #open_2finger_same_type('index_finger',_velo,_acce)
    #open_2finger_same_type('middle_finger',_velo,_acce)
    #open_2finger_same_type('ring_finger',_velo,_acce)
    #open_2finger_same_type('pinky_finger',_velo,_acce)
    
    mail.move_to_position(left_arm_2,0,time_3/2)
    mail.move_to_position(right_arm_2,0,time_3/2)

    mail.move_to_position(left_arm_1,1.1,time_3/2)
    mail.move_to_position(right_arm_1,-1.1,time_3/2)

    mail.move_to_position(left_arm_3,-math.pi/4,time_3/2)
    mail.move_to_position(right_arm_3,math.pi/4,time_3/2)

    time.sleep(time_3/10)

    mail.move_to_position(left_arm_5,0,time_3/2)
    mail.move_to_position(right_arm_5,0,time_3/2)

    time.sleep(time_3/2)
    ###############################################3
    ####################################
    #left_hand
    
#     ser_left.set_motor_data(3,0,_velo,_acce,True) #index finger up -> +
#     ser_left.set_motor_data(4,1600,_velo,_acce,True) #middle finger up -> +
#     ser_left.set_motor_data(5,1600,_velo,_acce,True) #ring finger up -> +
#     ser_left.set_motor_data(6,1600,_velo,_acce,True) #little finger up -> +
    #close_2finger_same_type('index_finger',0,_velo,_acce )
    #close_2finger_same_type('middle_finger',1600,_velo,_acce )
    #close_2finger_same_type('ring_finger',1600,_velo,_acce )
    #close_2finger_same_type('pinky_finger',1600,_velo,_acce )


    #teach_index_finger
    #init position
    mail.move_to_position(left_arm_0,-1.524,time_3/2)
    mail.move_to_position(left_arm_1,0.77,time_3/2)
    mail.move_to_position(right_arm_0,1.61,time_3/2)
    mail.move_to_position(right_arm_1,-0.854,time_3/2)

    mail.move_to_position(left_arm_2,1.53,time_3)
    mail.move_to_position(left_arm_4,0.01,time_3)
    mail.move_to_position(left_arm_5,0.175,time_3)



    mail.move_to_position(right_arm_2,-1.62,time_3)
    mail.move_to_position(right_arm_4,0.12,time_3)
    mail.move_to_position(right_arm_5,0.23,time_3)

    time.sleep(time_3)

    mail.move_to_position(left_arm_3,0.17,time_3/2)
    mail.move_to_position(right_arm_3,-0.15,time_3/2)

    time.sleep(time_3)


    ###############################################3
    
    #open arm
    mail.move_to_position(right_arm_3,0,time_3/2)
    mail.move_to_position(left_arm_3,0,time_3/2)

    
    time.sleep(time_3/2)
    #open_hand
    #ser_left.set_motor_data(3,0,_velo,_acce,True) #index finger up -> +
    #ser_left.set_motor_data(4,0,_velo,_acce,True) #middle finger up -> +
    #ser_left.set_motor_data(5,0,_velo,_acce,True) #ring finger up -> +
    #ser_left.set_motor_data(6,0,_velo,_acce,True) #little finger up -> +
    
    mail.move_to_position(left_arm_2,0,time_3/2)
    mail.move_to_position(right_arm_2,0,time_3/2)

    mail.move_to_position(left_arm_1,1.1,time_3/2)
    mail.move_to_position(right_arm_1,-1.1,time_3/2)

    mail.move_to_position(left_arm_3,-math.pi/4,time_3/2)
    mail.move_to_position(right_arm_3,math.pi/4,time_3/2)

    time.sleep(time_3/10)

    mail.move_to_position(left_arm_5,0,time_3/2)
    mail.move_to_position(right_arm_5,0,time_3/2)

    time.sleep(time_3/2)
    #left_hand
    
    #ser_left.set_motor_data(3,1600,_velo,_acce,True) #index finger up -> +
    #ser_left.set_motor_data(4,0,_velo,_acce,True) #middle finger up -> +
    #ser_left.set_motor_data(5,1600,_velo,_acce,True) #ring finger up -> +
    #ser_left.set_motor_data(6,1600,_velo,_acce,True) #little finger up -> +
    
    #teach_middle_finger
    #init position
    mail.move_to_position(left_arm_0,-1.524,time_3/2)
    mail.move_to_position(left_arm_1,0.777,time_3/2)
    mail.move_to_position(right_arm_0,1.61,time_3/2)
    mail.move_to_position(right_arm_1,-0.863,time_3/2)

    mail.move_to_position(left_arm_2,1.53,time_3)
    mail.move_to_position(left_arm_4,0.01,time_3)
    mail.move_to_position(left_arm_5,0.17,time_3)



    mail.move_to_position(right_arm_2,-1.62,time_3)
    mail.move_to_position(right_arm_4,0.12,time_3)
    mail.move_to_position(right_arm_5,0.23,time_3)

    time.sleep(time_3)

    mail.move_to_position(left_arm_3,0.17,time_3/2)
    mail.move_to_position(right_arm_3,-0.15,time_3/2)

    time.sleep(time_3)
    #########################################3
    
    #open arm
    mail.move_to_position(right_arm_3,0,time_3/2)
    mail.move_to_position(left_arm_3,0,time_3/2)

    
    time.sleep(time_3/2)
    #open_hand
    #ser_left.set_motor_data(3,0,_velo,_acce,True) #index finger up -> +
    #ser_left.set_motor_data(4,0,_velo,_acce,True) #middle finger up -> +
    #ser_left.set_motor_data(5,0,_velo,_acce,True) #ring finger up -> +
    #ser_left.set_motor_data(6,0,_velo,_acce,True) #little finger up -> +
    
    mail.move_to_position(left_arm_2,0,time_3/2)
    mail.move_to_position(right_arm_2,0,time_3/2)

    mail.move_to_position(left_arm_1,1.1,time_3/2)
    mail.move_to_position(right_arm_1,-1.1,time_3/2)

    mail.move_to_position(left_arm_3,-math.pi/4,time_3/2)
    mail.move_to_position(right_arm_3,math.pi/4,time_3/2)

    time.sleep(time_3/10)

    mail.move_to_position(left_arm_5,0,time_3/2)
    mail.move_to_position(right_arm_5,0,time_3/2)

    time.sleep(time_3/2)
    #left_hand
    
    #ser_left.set_motor_data(3,1600,_velo,_acce,True) #index finger up -> +
    #ser_left.set_motor_data(4,1600,_velo,_acce,True) #middle finger up -> +
    #ser_left.set_motor_data(5,0,_velo,_acce,True) #ring finger up -> +
    #ser_left.set_motor_data(6,1600,_velo,_acce,True) #little finger up -> +
    
  #teach_ring_finger
    #init position
    mail.move_to_position(left_arm_0,-1.524,time_3)
    mail.move_to_position(left_arm_1,0.778,time_3)
    mail.move_to_position(right_arm_0,1.61,time_3)
    mail.move_to_position(right_arm_1,-0.857,time_3)


    mail.move_to_position(left_arm_2,1.53,time_3)
    mail.move_to_position(left_arm_4,0.01,time_3)
    mail.move_to_position(left_arm_5,0.155,time_3)



    mail.move_to_position(right_arm_2,-1.62,time_3)
    mail.move_to_position(right_arm_4,0.12,time_3)
    mail.move_to_position(right_arm_5,0.23,time_3)

    time.sleep(time_3)

    mail.move_to_position(left_arm_3,0.17,time_3/2)
    mail.move_to_position(right_arm_3,-0.15,time_3/2)

    time.sleep(time_3)
    #########################################3
    
    #open arm
    mail.move_to_position(right_arm_3,0,time_3/2)
    mail.move_to_position(left_arm_3,0,time_3/2)

    
    time.sleep(time_3/2)
    #open_hand
    #ser_left.set_motor_data(3,0,_velo,_acce,True) #index finger up -> +
    #ser_left.set_motor_data(4,0,_velo,_acce,True) #middle finger up -> +
    #ser_left.set_motor_data(5,0,_velo,_acce,True) #ring finger up -> +
    #ser_left.set_motor_data(6,0,_velo,_acce,True) #little finger up -> +
    
    mail.move_to_position(left_arm_2,0,time_3/2)
    mail.move_to_position(right_arm_2,0,time_3/2)

    mail.move_to_position(left_arm_1,1.1,time_3/2)
    mail.move_to_position(right_arm_1,-1.1,time_3/2)

    mail.move_to_position(left_arm_3,-math.pi/4,time_3/2)
    mail.move_to_position(right_arm_3,math.pi/4,time_3/2)

    time.sleep(time_3/10)

    mail.move_to_position(left_arm_5,0,time_3/2)
    mail.move_to_position(right_arm_5,0,time_3/2)

    time.sleep(time_3/2)
    #left_hand
    
    #ser_left.set_motor_data(3,1600,_velo,_acce,True) #index finger up -> +
    #ser_left.set_motor_data(4,1600,_velo,_acce,True) #middle finger up -> +
    #ser_left.set_motor_data(5,1600,_velo,_acce,True) #ring finger up -> +
    #ser_left.set_motor_data(6,0,_velo,_acce,True) #little finger up -> +
    
    #teach_little_finger
    #init position
    mail.move_to_position(left_arm_0,-1.524,time_3)
    mail.move_to_position(left_arm_1,0.74,time_3)
    mail.move_to_position(right_arm_0,1.61,time_3)
    mail.move_to_position(right_arm_1,-0.78,time_3)


    mail.move_to_position(left_arm_2,1.53,time_3)
    mail.move_to_position(left_arm_4,0.01,time_3)
    mail.move_to_position(left_arm_5,0.155,time_3)

    mail.move_to_position(right_arm_2,-1.62,time_3)
    mail.move_to_position(right_arm_4,0.12,time_3)
    mail.move_to_position(right_arm_5,0.23,time_3)

    time.sleep(time_3)

    mail.move_to_position(left_arm_3,0.17,time_3/2)
    mail.move_to_position(right_arm_3,-0.15,time_3/2)

    time.sleep(time_3)


    
#home
time_3=5
mail.move_to_position(right_arm_3,0,time_3/2)
mail.move_to_position(left_arm_3,0,time_3/2)

time.sleep(time_3)
mail.move_to_position(left_arm_2,0,time_3)
mail.move_to_position(right_arm_2,0,time_3)

time.sleep(time_3)


mail.move_to_position(right_arm_0,0,time_3)
mail.move_to_position(right_arm_1,0,time_3)
mail.move_to_position(right_arm_3,0,time_3)
mail.move_to_position(right_arm_4,0,time_3)
mail.move_to_position(right_arm_5,0,time_3)

mail.move_to_position(left_arm_0,0,time_3)
mail.move_to_position(left_arm_1,0,time_3)
mail.move_to_position(left_arm_3,0,time_3)
mail.move_to_position(left_arm_4,0,time_3)
mail.move_to_position(left_arm_5,0,time_3)
#ser_left.set_motor_data(3,0,_velo,_acce,True) #index finger up -> +
#ser_left.set_motor_data(4,0,_velo,_acce,True) #middle finger up -> +
#ser_left.set_motor_data(5,0,_velo,_acce,True) #ring finger up -> +
#ser_left.set_motor_data(6,0,_velo,_acce,True) #little finger up -> +
    
time.sleep(time_3)
# Out:
# current_pos:  0.00044868938045655005
# current velocity:  0.0
# move_array:  [-1589589   227151    75717    75717]
# current_pos:  6.998787344728238e-05
# current velocity:  0.0
# move_array:  [803139 114723  38241  38241]
# current_pos:  -0.00036911412708498243
# current velocity:  0.0
# move_array:  [2015149  287944   95981   95981]
# current_pos:  -5.113269292952137e-05
# current velocity:  0.0
# move_array:  [-1068905   152691    50897    50897]
# current_pos:  -7.31037719226751e-05
# current velocity:  -0.0009443569225420978
# move_array:  [1276678  182391   60797   60797]
# current_pos:  7.669903939428207e-06
# current velocity:  0.0
# move_array:  [5215  744  248  248]
# current_pos:  -4.601942363656923e-05
# current velocity:  0.0
# move_array:  [91265 13041  4347  4347]
# current_pos:  9.747169589690011e-05
# current velocity:  1.9973708175594287e-05
# move_array:  [-2027665   289683    96561    96561]
# current_pos:  0.00015531555477342116
# current velocity:  0.0
# ...

# %%
mail.move_to_position(right_arm_0,0,10)
# Out:
# current_pos:  1.609999123305299
# current velocity:  -0.000758201962345559
# move_array:  [     0 287878  95959  95959]
